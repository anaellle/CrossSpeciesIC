# %% [markdown]
# # Import packages

# %%
import scanpy as sc
import anndata
import numpy as np
import gc
import pandas as pd 
pd.set_option('display.max_columns', None)
from biomart import BiomartServer
from datetime import date
import os
gc.isenabled()
# Out:
# True

# %% [markdown]
# # Query the server

# %%
server = BiomartServer("http://www.ensembl.org/biomart")

# %%
ensembl = server.datasets['hsapiens_gene_ensembl']

# %%
columns = ['ensembl_gene_id','external_gene_name','mmusculus_homolog_ensembl_gene', 
           'mmusculus_homolog_orthology_type', 'mmusculus_homolog_associated_gene_name']

# %%
response = ensembl.search({'attributes' : columns,
                           'mart_instance' : 'ensembl'})

# %%
mapping_df = pd.read_csv(response.url, sep='\t', header=None, names=columns)

# %%
mapping_df
# Out:
#        ensembl_gene_id external_gene_name mmusculus_homolog_ensembl_gene
# 0      ENSG00000210049              MT-TF                            NaN  \
# 1      ENSG00000211459            MT-RNR1                            NaN
# 2      ENSG00000210077              MT-TV                            NaN
# 3      ENSG00000210082            MT-RNR2                            NaN
# 4      ENSG00000209082             MT-TL1                            NaN
# ...                ...                ...                            ...
# 75771  ENSG00000162437             RAVER2             ENSMUSG00000035275
# 75772  ENSG00000122432             SPATA1             ENSMUSG00000028188
# 75773  ENSG00000284882                NaN                            NaN
# 75774  ENSG00000289881                NaN                            NaN
# 75775  ENSG00000285325                NaN                            NaN
#
#       mmusculus_homolog_orthology_type mmusculus_homolog_associated_gene_name
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
# ...                                ...                                    ...
# 75771                 ortholog_one2one                                 Raver2
# 75772                 ortholog_one2one                                 Spata1
# 75773                              NaN                                    NaN
# 75774                              NaN                                    NaN
# 75775                              NaN                                    NaN
#
# [75776 rows x 5 columns]

# %%
columns2 = ['ensembl_gene_id','entrezgene_id']

# %% [markdown]
# New query because 'entrezgene_id' is not on the same page

# %%
response2 = ensembl.search({'attributes' : columns2,
                           'mart_instance' : 'ensembl'})

# %%
ncbi_id = pd.read_csv(response2.url, sep='\t', header=None, names=columns2)

# %% [markdown]
# # Import human and mouse data

# %%
os.path.realpath('ensembl_query.ipynb')
# Out:
# '/nfs/research/irene/anaelle/CrossSpeciesIC/expiMap/object_human_mouse/ensembl_query.ipynb'

# %%
path_project = '/nfs/research/irene/anaelle/CrossSpeciesIC/' #change this path to your directory
print(path_project)
path_scripts = os.path.join(path_project, 'expiMap', 'object_human_mouse') #change this path
print(path_scripts)
path_data = os.path.join(path_project, 'data')
print(path_data)

# %%
mouse_data = sc.read_h5ad(os.path.join(path_data,'mouse_raw_counts_from_cellxgene.h5ad'))

# %%
human_data = sc.read_h5ad(os.path.join(path_data, 'hdata2023-06-05.h5ad'))
# Out:
# /nfs/research/irene/anaelle/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /nfs/research/irene/anaelle/miniconda3/lib/python3.10/site-packages/anndata/_core/anndata.py:117: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %% [markdown]
# # Get the human genes

# %%
human_ncbi_id = ncbi_id[ncbi_id.entrezgene_id.isin(human_data.var.entrez_id)]

# %%
human_ncbi_id
# Out:
#        ensembl_gene_id  entrezgene_id
# 5      ENSG00000198888         4535.0
# 9      ENSG00000198763         4536.0
# 15     ENSG00000198804         4512.0
# 18     ENSG00000198712         4513.0
# 20     ENSG00000228253         4509.0
# ...                ...            ...
# 75101  ENSG00000198216          777.0
# 75102  ENSG00000179930       127665.0
# 75112  ENSG00000264470    100616338.0
# 75113  ENSG00000162437        55225.0
# 75114  ENSG00000122432    100505741.0
#
# [28838 rows x 2 columns]

# %%
human_mouse_df = mapping_df[mapping_df.ensembl_gene_id.isin(human_ncbi_id.ensembl_gene_id)]

# %%
human_mouse_df
# Out:
#        ensembl_gene_id external_gene_name mmusculus_homolog_ensembl_gene
# 5      ENSG00000198888             MT-ND1             ENSMUSG00000064341  \
# 9      ENSG00000198763             MT-ND2             ENSMUSG00000064345
# 15     ENSG00000198804             MT-CO1             ENSMUSG00000064351
# 18     ENSG00000198712             MT-CO2             ENSMUSG00000064354
# 20     ENSG00000228253            MT-ATP8             ENSMUSG00000064356
# ...                ...                ...                            ...
# 75759  ENSG00000198216            CACNA1E             ENSMUSG00000004110
# 75760  ENSG00000179930             ZNF648             ENSMUSG00000066797
# 75770  ENSG00000264470            MIR4794                            NaN
# 75771  ENSG00000162437             RAVER2             ENSMUSG00000035275
# 75772  ENSG00000122432             SPATA1             ENSMUSG00000028188
#
#       mmusculus_homolog_orthology_type mmusculus_homolog_associated_gene_name
# 5                     ortholog_one2one                                 mt-Nd1
# 9                     ortholog_one2one                                 mt-Nd2
# 15                    ortholog_one2one                                 mt-Co1
# 18                    ortholog_one2one                                 mt-Co2
# 20                    ortholog_one2one                                mt-Atp8
# ...                                ...                                    ...
# 75759                 ortholog_one2one                                Cacna1e
# 75760                 ortholog_one2one                                 Zfp648
# 75770                              NaN                                    NaN
# 75771                 ortholog_one2one                                 Raver2
# 75772                 ortholog_one2one                                 Spata1
#
# [33290 rows x 5 columns]

# %% [markdown]
# # Get the mouse genes

# %%
mouse_data.var.index
# Out:
# Index(['ENSMUSG00000029422', 'ENSMUSG00000114536', 'ENSMUSG00000049036',
#        'ENSMUSG00000029577', 'ENSMUSG00000040746', 'ENSMUSG00000020590',
#        'ENSMUSG00000096963', 'ENSMUSG00000030263', 'ENSMUSG00000038914',
#        'ENSMUSG00000098447',
#        ...
#        'ENSMUSG00000101706', 'ENSMUSG00000073052', 'ENSMUSG00000113410',
#        'ENSMUSG00000102368', 'ENSMUSG00000021033', 'ENSMUSG00000100416',
#        'ENSMUSG00000096169', 'ENSMUSG00000030657', 'ENSMUSG00000037924',
#        'ENSMUSG00000040693'],
#       dtype='object', name='feature_id', length=30639)

# %%
human_mouse_df = human_mouse_df[human_mouse_df.mmusculus_homolog_ensembl_gene.isin(mouse_data.var.index)]

# %%
human_mouse_df
# Out:
#        ensembl_gene_id external_gene_name mmusculus_homolog_ensembl_gene
# 5      ENSG00000198888             MT-ND1             ENSMUSG00000064341  \
# 9      ENSG00000198763             MT-ND2             ENSMUSG00000064345
# 15     ENSG00000198804             MT-CO1             ENSMUSG00000064351
# 18     ENSG00000198712             MT-CO2             ENSMUSG00000064354
# 20     ENSG00000228253            MT-ATP8             ENSMUSG00000064356
# ...                ...                ...                            ...
# 75758  ENSG00000187017               ESPN             ENSMUSG00000028943
# 75759  ENSG00000198216            CACNA1E             ENSMUSG00000004110
# 75760  ENSG00000179930             ZNF648             ENSMUSG00000066797
# 75771  ENSG00000162437             RAVER2             ENSMUSG00000035275
# 75772  ENSG00000122432             SPATA1             ENSMUSG00000028188
#
#       mmusculus_homolog_orthology_type mmusculus_homolog_associated_gene_name
# 5                     ortholog_one2one                                 mt-Nd1
# 9                     ortholog_one2one                                 mt-Nd2
# 15                    ortholog_one2one                                 mt-Co1
# 18                    ortholog_one2one                                 mt-Co2
# 20                    ortholog_one2one                                mt-Atp8
# ...                                ...                                    ...
# 75758                 ortholog_one2one                                   Espn
# 75759                 ortholog_one2one                                Cacna1e
# 75760                 ortholog_one2one                                 Zfp648
# 75771                 ortholog_one2one                                 Raver2
# 75772                 ortholog_one2one                                 Spata1
#
# [22051 rows x 5 columns]

# %%
human_mouse_df.ensembl_gene_id.duplicated().sum()
# Out:
# 4583

# %%
human_mouse_df.mmusculus_homolog_ensembl_gene.duplicated().sum()
# Out:
# 3673

# %% [markdown]
# # Add the entrezgene_id

# %%
human_ncbi_id
# Out:
#        ensembl_gene_id  entrezgene_id
# 5      ENSG00000198888         4535.0
# 9      ENSG00000198763         4536.0
# 15     ENSG00000198804         4512.0
# 18     ENSG00000198712         4513.0
# 20     ENSG00000228253         4509.0
# ...                ...            ...
# 75101  ENSG00000198216          777.0
# 75102  ENSG00000179930       127665.0
# 75112  ENSG00000264470    100616338.0
# 75113  ENSG00000162437        55225.0
# 75114  ENSG00000122432    100505741.0
#
# [28838 rows x 2 columns]

# %%
human_ncbi_id.ensembl_gene_id.duplicated().sum()
# Out:
# 290

# %% [markdown]
# ## Check ids duplicates

# %%
human_ncbi_id[human_ncbi_id.ensembl_gene_id.duplicated()]
# Out:
#        ensembl_gene_id  entrezgene_id
# 724    ENSG00000267635    100507608.0
# 905    ENSG00000275517       653247.0
# 987    ENSG00000273772         6607.0
# 1049   ENSG00000276910       728340.0
# 1058   ENSG00000274166       647042.0
# ...                ...            ...
# 74887  ENSG00000290825    100287102.0
# 74888  ENSG00000290825    100287596.0
# 74889  ENSG00000290825    102725121.0
# 74942  ENSG00000291158       388692.0
# 74976  ENSG00000158747    100532736.0
#
# [290 rows x 2 columns]

# %%
duplicates = human_ncbi_id[human_ncbi_id.ensembl_gene_id.isin(human_ncbi_id[human_ncbi_id.ensembl_gene_id.duplicated()].ensembl_gene_id)]

# %%
duplicates
# Out:
#        ensembl_gene_id  entrezgene_id
# 723    ENSG00000267635    100505724.0
# 724    ENSG00000267635    100507608.0
# 904    ENSG00000275517         5542.0
# 905    ENSG00000275517       653247.0
# 986    ENSG00000273772         6606.0
# ...                ...            ...
# 74889  ENSG00000290825    102725121.0
# 74941  ENSG00000291158        57234.0
# 74942  ENSG00000291158       388692.0
# 74975  ENSG00000158747         4681.0
# 74976  ENSG00000158747    100532736.0
#
# [556 rows x 2 columns]

# %%
human_duplicates = {}
for index, row in duplicates.iterrows():
    if row['ensembl_gene_id'] not in human_duplicates.keys():
#  'ENSG00000203668': [1122.0, 23596.0],
#  'ENSG00000290355': [727856.0, 100287029.0],
#  'ENSG00000278848': [653550.0, 102724101.0, 102724127.0],
#  'ENSG00000205457': [653550.0, 102724101.0],
#  'ENSG00000233024': [100288332.0, 105376752.0],
#  'ENSG00000185164': [283820.0, 102723728.0],
#  'ENSG00000183426': [9284.0, 642799.0],
#  'ENSG00000251655': [5542.0, 653247.0],
#  'ENSG00000197837': [121504.0, 554313.0],
#  'ENSG00000188629': [7730.0, 100529215.0],
#  'ENSG00000236107': [101929680.0, 102724058.0],
#  'ENSG00000245552': [100129203.0, 101929295.0],
#  'ENSG00000273513': [101060351.0, 102723859.0],
#  'ENSG00000111215': [5554.0, 11272.0],
#  'ENSG00000151067': [775.0, 100874369.0],
#  'ENSG00000270882': [8370.0, 554313.0],
#  'ENSG00000196242': [81472.0, 148824.0],
#  'ENSG00000283154': [29970.0, 100505385.0],
#  'ENSG00000274808': [414059.0, 101060321.0],
#  'ENSG00000178882': [144347.0, 100533183.0],
#  'ENSG00000227036': [400619.0, 100499467.0],
#  'ENSG00000185829': [51326.0, 100506084.0],
#  'ENSG00000120088': [1394.0, 104909134.0],
#  'ENSG00000228696': [51326.0, 100506084.0],
#  'ENSG00000108379': [7473.0, 101929777.0],
#  'ENSG00000228262': [104355287.0, 104355288.0],
#  'ENSG00000237298': [100506866.0, 101927055.0],
#  'ENSG00000290614': [150527.0, 646743.0],
#  'ENSG00000229571': [441873.0, 645359.0],
#  'ENSG00000233008': [101927560.0, 101927587.0],
#  'ENSG00000284733': [81399.0, 729759.0],
#  'ENSG00000143702': [9859.0, 645455.0],
#  'ENSG00000290825': [84771.0, 727856.0, 100287102.0, 100287596.0, 102725121.0],
#  'ENSG00000291158': [57234.0, 388692.0],
#  'ENSG00000158747': [4681.0, 100532736.0]}

# %% [markdown]
# ## Keep only the first

# %%
genes_removed = []
for gene in human_duplicates.keys():
    for entrez_id in range(1,len(human_duplicates[gene])):
        genes_removed.append(human_duplicates[gene][entrez_id])

# %%
len(genes_removed) #Same length as the duplicates in human_ncbi_id df
# Out:
# 290

# %%
human_ncbi_id[~human_ncbi_id.entrezgene_id.isin(genes_removed)].duplicated().any()
# Out:
# False

# %%
human_genes = human_ncbi_id[~human_ncbi_id.entrezgene_id.isin(genes_removed)]

# %%
human_genes.ensembl_gene_id.duplicated().any()
# Out:
# False

# %%
human_genes.loc[human_genes.ensembl_gene_id == 'ENSG00000198888'].entrezgene_id.iloc[0]
# Out:
# 4535.0

# %%
'ENSG00000198804' in human_genes.ensembl_gene_id.values
# Out:
# True

# %%
human_genes
# Out:
#        ensembl_gene_id  entrezgene_id
# 5      ENSG00000198888         4535.0
# 9      ENSG00000198763         4536.0
# 15     ENSG00000198804         4512.0
# 18     ENSG00000198712         4513.0
# 20     ENSG00000228253         4509.0
# ...                ...            ...
# 75101  ENSG00000198216          777.0
# 75102  ENSG00000179930       127665.0
# 75112  ENSG00000264470    100616338.0
# 75113  ENSG00000162437        55225.0
# 75114  ENSG00000122432    100505741.0
#
# [28485 rows x 2 columns]

# %% [markdown]
# ## Check entrez_id doublets

# %%
human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.duplicated()]
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 16          ENSG00000198692               9086.0                   EIF1AY  \
# 17          ENSG00000198692               9086.0                   EIF1AY
# 18          ENSG00000198692               9086.0                   EIF1AY
# 19          ENSG00000198692               9086.0                   EIF1AY
# 20          ENSG00000198692               9086.0                   EIF1AY
# ...                     ...                  ...                      ...
# 21880       ENSG00000143549               7170.0                     TPM3
# 21931       ENSG00000241128             388761.0                   OR14A2
# 21932       ENSG00000241128             388761.0                   OR14A2
# 21933       ENSG00000241128             388761.0                   OR14A2
# 21934       ENSG00000241128             388761.0                   OR14A2
#
#       mouse_homolog_ensembl_gene     orthology_type mouse_homolog_gene_name
# 16            ENSMUSG00000113201  ortholog_one2many                Eif1ad13
# 17            ENSMUSG00000079031  ortholog_one2many                 Eif1ad2
# 18            ENSMUSG00000079029  ortholog_one2many                 Eif1ad7
# 19            ENSMUSG00000093847  ortholog_one2many                Eif1ad15
# 20            ENSMUSG00000113971  ortholog_one2many                 Eif1ad4
# ...                          ...                ...                     ...
# 21880         ENSMUSG00000058126  ortholog_one2many                Tpm3-rs7
# 21931         ENSMUSG00000055610  ortholog_one2many                Or14a260
# 21932         ENSMUSG00000062042  ortholog_one2many                Or14a256
# 21933         ENSMUSG00000055571  ortholog_one2many                Or14a259
# 21934         ENSMUSG00000062426  ortholog_one2many                Or14a258
#
# [4510 rows x 6 columns]

# %%
entrez_dup = human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.isin(human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.duplicated()].human_entrezgene_id)]

# %%
entrez_dup
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 13          ENSG00000277196               5625.0                    PRODH  \
# 15          ENSG00000198692               9086.0                   EIF1AY
# 16          ENSG00000198692               9086.0                   EIF1AY
# 17          ENSG00000198692               9086.0                   EIF1AY
# 18          ENSG00000198692               9086.0                   EIF1AY
# ...                     ...                  ...                      ...
# 21930       ENSG00000241128             388761.0                   OR14A2
# 21931       ENSG00000241128             388761.0                   OR14A2
# 21932       ENSG00000241128             388761.0                   OR14A2
# 21933       ENSG00000241128             388761.0                   OR14A2
# 21934       ENSG00000241128             388761.0                   OR14A2
#
#       mouse_homolog_ensembl_gene     orthology_type mouse_homolog_gene_name
# 13            ENSMUSG00000003526  ortholog_one2many                   Prodh
# 15            ENSMUSG00000057561  ortholog_one2many                   Eif1a
# 16            ENSMUSG00000113201  ortholog_one2many                Eif1ad13
# 17            ENSMUSG00000079031  ortholog_one2many                 Eif1ad2
# 18            ENSMUSG00000079029  ortholog_one2many                 Eif1ad7
# ...                          ...                ...                     ...
# 21930         ENSMUSG00000062878  ortholog_one2many                Or14a257
# 21931         ENSMUSG00000055610  ortholog_one2many                Or14a260
# 21932         ENSMUSG00000062042  ortholog_one2many                Or14a256
# 21933         ENSMUSG00000055571  ortholog_one2many                Or14a259
# 21934         ENSMUSG00000062426  ortholog_one2many                Or14a258
#
# [5269 rows x 6 columns]

# %%
entrezid = {}
for index, row in entrez_dup.iterrows():
    if row['human_entrezgene_id'] not in entrezid.keys():
        entrezid[row['human_entrezgene_id']] = []
    if row.human_ensembl_gene_id not in entrezid[row['human_entrezgene_id']]:
        entrezid[row['human_entrezgene_id']].append(row.human_ensembl_gene_id)

# %%
len(entrezid.keys())
# Out:
# 759

# %% [markdown]
# ## Create new dataframe

# %%
human_mouse_df.head(20)
# Out:
#       ensembl_gene_id external_gene_name mmusculus_homolog_ensembl_gene
# 5     ENSG00000198888             MT-ND1             ENSMUSG00000064341  \
# 9     ENSG00000198763             MT-ND2             ENSMUSG00000064345
# 15    ENSG00000198804             MT-CO1             ENSMUSG00000064351
# 18    ENSG00000198712             MT-CO2             ENSMUSG00000064354
# 20    ENSG00000228253            MT-ATP8             ENSMUSG00000064356
# 21    ENSG00000198899            MT-ATP6             ENSMUSG00000064357
# 22    ENSG00000198938             MT-CO3             ENSMUSG00000064358
# 24    ENSG00000198840             MT-ND3             ENSMUSG00000064360
# 26    ENSG00000212907            MT-ND4L             ENSMUSG00000065947
# 27    ENSG00000198886             MT-ND4             ENSMUSG00000064363
# 31    ENSG00000198786             MT-ND5             ENSMUSG00000064367
# 32    ENSG00000198695             MT-ND6             ENSMUSG00000064368
# 34    ENSG00000198727             MT-CYB             ENSMUSG00000064370
# 318   ENSG00000277196              PRODH             ENSMUSG00000003526
# 3005  ENSG00000114374              USP9Y             ENSMUSG00000069044
# 3147  ENSG00000198692             EIF1AY             ENSMUSG00000057561
# 3148  ENSG00000198692             EIF1AY             ENSMUSG00000113201
# 3149  ENSG00000198692             EIF1AY             ENSMUSG00000079031
# 3150  ENSG00000198692             EIF1AY             ENSMUSG00000079029
# 3151  ENSG00000198692             EIF1AY             ENSMUSG00000093847
#
#      mmusculus_homolog_orthology_type mmusculus_homolog_associated_gene_name
# 5                    ortholog_one2one                                 mt-Nd1
# 9                    ortholog_one2one                                 mt-Nd2
# 15                   ortholog_one2one                                 mt-Co1
# 18                   ortholog_one2one                                 mt-Co2
# 20                   ortholog_one2one                                mt-Atp8
# 21                   ortholog_one2one                                mt-Atp6
# 22                   ortholog_one2one                                 mt-Co3
# 24                   ortholog_one2one                                 mt-Nd3
# 26                   ortholog_one2one                                mt-Nd4l
# 27                   ortholog_one2one                                 mt-Nd4
# 31                   ortholog_one2one                                 mt-Nd5
# 32                   ortholog_one2one                                 mt-Nd6
# 34                   ortholog_one2one                                mt-Cytb
# 318                 ortholog_one2many                                  Prodh
# 3005                 ortholog_one2one                                  Usp9y
# 3147                ortholog_one2many                                  Eif1a
# 3148                ortholog_one2many                               Eif1ad13
# 3149                ortholog_one2many                                Eif1ad2
# 3150                ortholog_one2many                                Eif1ad7
# 3151                ortholog_one2many                               Eif1ad15

# %%
human_mouse_df.loc[human_mouse_df['ensembl_gene_id']=='ENSG00000198888']
# Out:
#    ensembl_gene_id external_gene_name mmusculus_homolog_ensembl_gene
# 5  ENSG00000198888             MT-ND1             ENSMUSG00000064341  \
#
#   mmusculus_homolog_orthology_type mmusculus_homolog_associated_gene_name
# 5                 ortholog_one2one                                 mt-Nd1

# %%
human_mouse_df.loc[human_mouse_df['ensembl_gene_id']=='ENSG00000198888'].external_gene_name
# Out:
# 5    MT-ND1
# Name: external_gene_name, dtype: object

# %%
human_mouse_df.mmusculus_homolog_ensembl_gene.hasnans
# Out:
# False

# %%
def get_ensembl_gene_info_df():
    rows = []
    for index, row in human_mouse_df.iterrows():
        ensembl_id = row['ensembl_gene_id']
        if ensembl_id in human_genes['ensembl_gene_id'].values:
            entrez_id = human_genes.loc[human_genes['ensembl_gene_id']==ensembl_id].entrezgene_id.iloc[0]
            gene_now ={}
            gene_now['human_ensembl_gene_id'] = ensembl_id
            gene_now['human_entrezgene_id'] = entrez_id
            gene_now['human_external_gene_name'] = row['external_gene_name']
            gene_now['mouse_homolog_ensembl_gene'] = row['mmusculus_homolog_ensembl_gene']
            gene_now['orthology_type'] = row['mmusculus_homolog_orthology_type']
            gene_now['mouse_homolog_gene_name'] = row['mmusculus_homolog_associated_gene_name']
            rows.append(gene_now)
    return rows

# %%
rows = get_ensembl_gene_info_df()

# %%
human_mouse_homolog_genes = pd.DataFrame(rows)

# %%
human_mouse_homolog_genes
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 0           ENSG00000198888               4535.0                   MT-ND1  \
# 1           ENSG00000198763               4536.0                   MT-ND2
# 2           ENSG00000198804               4512.0                   MT-CO1
# 3           ENSG00000198712               4513.0                   MT-CO2
# 4           ENSG00000228253               4509.0                  MT-ATP8
# ...                     ...                  ...                      ...
# 21936       ENSG00000187017              83715.0                     ESPN
# 21937       ENSG00000198216                777.0                  CACNA1E
# 21938       ENSG00000179930             127665.0                   ZNF648
# 21939       ENSG00000162437              55225.0                   RAVER2
# 21940       ENSG00000122432          100505741.0                   SPATA1
#
#       mouse_homolog_ensembl_gene    orthology_type mouse_homolog_gene_name
# 0             ENSMUSG00000064341  ortholog_one2one                  mt-Nd1
# 1             ENSMUSG00000064345  ortholog_one2one                  mt-Nd2
# 2             ENSMUSG00000064351  ortholog_one2one                  mt-Co1
# 3             ENSMUSG00000064354  ortholog_one2one                  mt-Co2
# 4             ENSMUSG00000064356  ortholog_one2one                 mt-Atp8
# ...                          ...               ...                     ...
# 21936         ENSMUSG00000028943  ortholog_one2one                    Espn
# 21937         ENSMUSG00000004110  ortholog_one2one                 Cacna1e
# 21938         ENSMUSG00000066797  ortholog_one2one                  Zfp648
# 21939         ENSMUSG00000035275  ortholog_one2one                  Raver2
# 21940         ENSMUSG00000028188  ortholog_one2one                  Spata1
#
# [21941 rows x 6 columns]

# %%
human_mouse_homolog_genes.human_ensembl_gene_id.duplicated().any()
# Out:
# True

# %%
human_mouse_homolog_genes.mouse_homolog_ensembl_gene.duplicated().any()
# Out:
# True

# %%
human_mouse_homolog_genes.human_entrezgene_id.hasnans
# Out:
# False

# %%
human_mouse_homolog_genes.mouse_homolog_ensembl_gene.hasnans
# Out:
# False

# %%
human_mouse_homolog_genes.orthology_type.hasnans
# Out:
# False

# %%
human_mouse_homolog_genes.orthology_type.unique()
# Out:
# array(['ortholog_one2one', 'ortholog_one2many', 'ortholog_many2many'],
#       dtype=object)

# %% [markdown]
# ## Check entrez duplicates

# %%
human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.duplicated()]
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 16          ENSG00000198692               9086.0                   EIF1AY  \
# 17          ENSG00000198692               9086.0                   EIF1AY
# 18          ENSG00000198692               9086.0                   EIF1AY
# 19          ENSG00000198692               9086.0                   EIF1AY
# 20          ENSG00000198692               9086.0                   EIF1AY
# ...                     ...                  ...                      ...
# 21880       ENSG00000143549               7170.0                     TPM3
# 21931       ENSG00000241128             388761.0                   OR14A2
# 21932       ENSG00000241128             388761.0                   OR14A2
# 21933       ENSG00000241128             388761.0                   OR14A2
# 21934       ENSG00000241128             388761.0                   OR14A2
#
#       mouse_homolog_ensembl_gene     orthology_type mouse_homolog_gene_name
# 16            ENSMUSG00000113201  ortholog_one2many                Eif1ad13
# 17            ENSMUSG00000079031  ortholog_one2many                 Eif1ad2
# 18            ENSMUSG00000079029  ortholog_one2many                 Eif1ad7
# 19            ENSMUSG00000093847  ortholog_one2many                Eif1ad15
# 20            ENSMUSG00000113971  ortholog_one2many                 Eif1ad4
# ...                          ...                ...                     ...
# 21880         ENSMUSG00000058126  ortholog_one2many                Tpm3-rs7
# 21931         ENSMUSG00000055610  ortholog_one2many                Or14a260
# 21932         ENSMUSG00000062042  ortholog_one2many                Or14a256
# 21933         ENSMUSG00000055571  ortholog_one2many                Or14a259
# 21934         ENSMUSG00000062426  ortholog_one2many                Or14a258
#
# [4510 rows x 6 columns]

# %%
entrez_dup = human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.isin(human_mouse_homolog_genes[human_mouse_homolog_genes.human_entrezgene_id.duplicated()].human_entrezgene_id)]

# %%
entrez_dup
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 13          ENSG00000277196               5625.0                    PRODH  \
# 15          ENSG00000198692               9086.0                   EIF1AY
# 16          ENSG00000198692               9086.0                   EIF1AY
# 17          ENSG00000198692               9086.0                   EIF1AY
# 18          ENSG00000198692               9086.0                   EIF1AY
# ...                     ...                  ...                      ...
# 21930       ENSG00000241128             388761.0                   OR14A2
# 21931       ENSG00000241128             388761.0                   OR14A2
# 21932       ENSG00000241128             388761.0                   OR14A2
# 21933       ENSG00000241128             388761.0                   OR14A2
# 21934       ENSG00000241128             388761.0                   OR14A2
#
#       mouse_homolog_ensembl_gene     orthology_type mouse_homolog_gene_name
# 13            ENSMUSG00000003526  ortholog_one2many                   Prodh
# 15            ENSMUSG00000057561  ortholog_one2many                   Eif1a
# 16            ENSMUSG00000113201  ortholog_one2many                Eif1ad13
# 17            ENSMUSG00000079031  ortholog_one2many                 Eif1ad2
# 18            ENSMUSG00000079029  ortholog_one2many                 Eif1ad7
# ...                          ...                ...                     ...
# 21930         ENSMUSG00000062878  ortholog_one2many                Or14a257
# 21931         ENSMUSG00000055610  ortholog_one2many                Or14a260
# 21932         ENSMUSG00000062042  ortholog_one2many                Or14a256
# 21933         ENSMUSG00000055571  ortholog_one2many                Or14a259
# 21934         ENSMUSG00000062426  ortholog_one2many                Or14a258
#
# [5269 rows x 6 columns]

# %%
entrezid = {}
for index, row in entrez_dup.iterrows():
    if row['human_entrezgene_id'] not in entrezid.keys():
        entrezid[row['human_entrezgene_id']] = []
    if row.human_ensembl_gene_id not in entrezid[row['human_entrezgene_id']]:
        entrezid[row['human_entrezgene_id']].append(row.human_ensembl_gene_id)

# %%
len(entrezid.keys())
# Out:
# 759

# %%
real_duplicates = {}
for gene in entrezid.keys():
    if len(entrezid[gene])>1:
        real_duplicates[gene] = entrezid[gene]

# %%
real_duplicates
# Out:
# {5625.0: ['ENSG00000277196', 'ENSG00000100033'],
#  54471.0: ['ENSG00000100335', 'ENSG00000285025'],
#  8195.0: ['ENSG00000125863', 'ENSG00000285508', 'ENSG00000285723'],
#  6606.0: ['ENSG00000205571', 'ENSG00000172062'],
#  29057.0: ['ENSG00000268350', 'ENSG00000179304'],
#  1159.0: ['ENSG00000237289', 'ENSG00000223572'],
#  552900.0: ['ENSG00000169627', 'ENSG00000183336'],
#  79008.0: ['ENSG00000132207', 'ENSG00000181625'],
#  3963.0: ['ENSG00000178934', 'ENSG00000205076'],
#  1673.0: ['ENSG00000177257', 'ENSG00000171711'],
#  55894.0: ['ENSG00000177243', 'ENSG00000176797'],
#  245908.0: ['ENSG00000186599', 'ENSG00000186562'],
#  245910.0: ['ENSG00000198129', 'ENSG00000186572'],
#  10156.0: ['ENSG00000105808', 'ENSG00000170667'],
#  643862.0: ['ENSG00000262461',
#   'ENSG00000275976',
#   'ENSG00000186645',
#   'ENSG00000274570',
#   'ENSG00000273520'],
#  641776.0: ['ENSG00000286038', 'ENSG00000286014', 'ENSG00000286137'],
#  51326.0: ['ENSG00000185829', 'ENSG00000228696']}

# %%
human_mouse_homolog_genes
# Out:
#       human_ensembl_gene_id  human_entrezgene_id human_external_gene_name
# 0           ENSG00000198888               4535.0                   MT-ND1  \
# 1           ENSG00000198763               4536.0                   MT-ND2
# 2           ENSG00000198804               4512.0                   MT-CO1
# 3           ENSG00000198712               4513.0                   MT-CO2
# 4           ENSG00000228253               4509.0                  MT-ATP8
# ...                     ...                  ...                      ...
# 21936       ENSG00000187017              83715.0                     ESPN
# 21937       ENSG00000198216                777.0                  CACNA1E
# 21938       ENSG00000179930             127665.0                   ZNF648
# 21939       ENSG00000162437              55225.0                   RAVER2
# 21940       ENSG00000122432          100505741.0                   SPATA1
#
#       mouse_homolog_ensembl_gene    orthology_type mouse_homolog_gene_name
# 0             ENSMUSG00000064341  ortholog_one2one                  mt-Nd1
# 1             ENSMUSG00000064345  ortholog_one2one                  mt-Nd2
# 2             ENSMUSG00000064351  ortholog_one2one                  mt-Co1
# 3             ENSMUSG00000064354  ortholog_one2one                  mt-Co2
# 4             ENSMUSG00000064356  ortholog_one2one                 mt-Atp8
# ...                          ...               ...                     ...
# 21936         ENSMUSG00000028943  ortholog_one2one                    Espn
# 21937         ENSMUSG00000004110  ortholog_one2one                 Cacna1e
# 21938         ENSMUSG00000066797  ortholog_one2one                  Zfp648
# 21939         ENSMUSG00000035275  ortholog_one2one                  Raver2
# 21940         ENSMUSG00000028188  ortholog_one2one                  Spata1
#
# [21941 rows x 6 columns]

# %% [markdown]
# # Write the results

# %%
human_mouse_homolog_genes.to_csv(os.path.join(path_data, 'homolog_human_mouse_ensembl_gene.csv'))
